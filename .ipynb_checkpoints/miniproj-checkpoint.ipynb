# %%
import csv, sys, os, re
from collections import Counter
import numpy
from matplotlib import pyplot
from sklearn.cluster import KMeans, AgglomerativeClustering
from collections import defaultdict

word_pattern = re.compile("\w[\w\-\']*\w|\w")

# %%
documents = []

with open("./data/metadata.csv", encoding="utf-8") as reader:
    csv_reader = csv.DictReader(reader)
    for document in csv_reader:
        try:
            with open("./data/{}".format(document["Filename"]), encoding="utf-8") as reader:
                print(document["Author"] + " / " + document["Title"])

                lines = []
                for line in reader:
                    lines.append(line.rstrip())

                text = " ".join(lines)
                document["Text"] = text
                document["Tokens"] = word_pattern.findall(text)
                document["Horror"] = "Horror" in document["Genre"] 
                
                documents.append(document)
        except Exception as e:
            print("! Problem with {}: {}".format(document["Filename"], e))
# Out:
# Austen, Jane / Emma
# Austen, Jane / Persuasion
# Austen, Jane / Pride and Prejudice
# Austen, Jane / Sense and Sensibility
# ! Problem with baring_gould_the_book_of_werewolves_pg5324.txt: [Errno 2] No such file or directory: './data/baring_gould_the_book_of_werewolves_pg5324.txt'
# Baum, Lyman Frank / Glinda of Oz
# Baum, Lyman Frank / The Wonderful Wizard of Oz
# Beckford, William / Vathek
# ! Problem with beckford_vathek_an_arabian_tale_pg42401.txt: 'utf-8' codec can't decode byte 0xd2 in position 1716: invalid continuation byte
# Bierce, Ambrose / An Occurrence at Owl Creek Bridge
# Bierce, Ambrose / Present at a Hanging and Other Ghost Stories
# Bierce, Ambrose / The Parenticide Club
# Bierce, Ambrose / The Damned Thing
# Birkhead, Edith / The Tale of Terror
# ! Problem with edith_the_tale_of_terror_pg14154.txt: 'utf-8' codec can't decode byte 0xe9 in position 6657: invalid continuation byte
# Blackwood, Algernon / The Damned
# Blackwood, Algernon / The Willows
# Blackwood, Algernon / Four Weird Tales
# Blackwood, Algernon / Day and Night Stories
# Blackwood, Algernon  / The Wendigo
# Blanchard, Amy Ella / A Sweet Little Maid
# Brontë, Charlotte / Jane Eyre: An Autobiography
# Brontë, Emily / Wuthering Heights
# Bulfinch, Thomas / Bulfinch's Mythology
# Butler, Samuel / The Odyssey
# Carroll, Lewis / Alice's Adventures in Wonderland
# ! Problem with chambers_the_king_in_yellow_pg8492.txt: [Errno 2] No such file or directory: './data/chambers_the_king_in_yellow_pg8492.txt'
# Christie, Agatha / The Murder on the Links
# Christie, Agatha / The Secret Adversary
# Collins, Wilkie / The Moonstone
# Conrad, Joseph / Heart of Darkness
# de Balzac, Honoré / La Grande Breteche
# Dickens, Charles / A Christmas Carol
# Dickens, Charles / Great Expectations
# Dickens, Charles / A Tale of Two Cities
# Dickens, Charles / Oliver Twist
# Dickens, Charles / A Christmas Carol
# Doyle, Arthur Conan / A Study in Scarlet
# Doyle, Arthur Conan / Tales of Terror and Mystery
# Doyle, Arthur Conan / The Adventure Of Sherlock Holmes
# Doyle, Arthur Conan / The Hound of The Baskervilles
# Doyle, Arthur Conan / The Parasite
# Doyle, Arthur Conan / Round the Fire Stories
# Dumas, Alexandre / The Three Musketeers
# Dumas, Alexandre / The Man in the Iron Mask
# Dumas, Alexandre / The Count of Monte Cristo
# Dunsany, Lord / The Book of Wonder
# Falkner, John Meade / The Lost Stradivarius
# ! Problem with falkner_the_lost_stradivarius_pg14107.txt: 'utf-8' codec can't decode byte 0xbe in position 1411: invalid start byte
# Fang, Irving / The Used People Lot
# Farjeon, B. L. / The House of the White Shadows
# Fitzgerald, Francis Scott / The Beautiful and the Damned
# Fitzgerald, Francis Scott / This Side of Paradise
# Fletcher Joseph / The Markenmore Mystery
# Fletcher, J. S. / The Middle of Things
# ! Problem with : [Errno 21] Is a directory: './data/'
# Gautier, Théophile / Clarimonde
# Gautier, Théophile / The Mummy's Foot
# Gilman, Charlotte Perkins  / The Yellow Wallpaper
# Glad, Victoria / Each Man Kills
# ! Problem with hawthone_the_scarlet_letter_pg25344.txt: [Errno 2] No such file or directory: './data/hawthone_the_scarlet_letter_pg25344.txt'
# Hearn, Lafcadio / Kwaidan Stories and Studies of Strange Things
# Hearn, Lafcadio / Shadowings
# ! Problem with hearn_shadowings_pg34215.txt: 'utf-8' codec can't decode byte 0xd1 in position 291: invalid continuation byte
# Hewlett, Maurice / The Forest Lovers
# Hobbes, Thomas / Leviathan
# ! Problem with hodgson_the_night_land_pg10662.txt: [Errno 2] No such file or directory: './data/hodgson_the_night_land_pg10662.txt'
# Hodgson, William / The House on the Borderland
# Hodgson, William / The Boats of the "Glen Carrig"
# Homer / The Illiad
# Hoover, Thomas / Life Blood
# Hornung, Ernest / Dead Men Tell No Tales
# Hugo, Victor / Notre Dame de Paris
# Hugo, Victor / Les Miserables
# Ibsen, Henrik / Gengangere
# Irving, Washington / The Legend of Sleepy Hollow
# Barrie, J.M. / Peter Pan
# Jacobs, W.W. / The Monkey's Paw
# Jacobs, W.W. / The Well
# James, Henry / The Turn of the Screw
# James, Montague Rhodes / Ghost Story of an Antiquary
# James, Montague Rhodes / A Thin Ghost and Others
# Joyce, James / Dubliners
# ! Problem with james_joyce_ulysses.txt: [Errno 2] No such file or directory: './data/james_joyce_ulysses.txt'
# Kafka, Franz / Metamorphosis
# ! Problem with the_trial_7849.txt: [Errno 2] No such file or directory: './data/the_trial_7849.txt'
# Kafka, Franz  / The Trial
# ! Problem with : [Errno 21] Is a directory: './data/'
# LeBlanc, Maurice / The Crystal Stopper
# LeBlanc, Maurice / The Teeth of the Tiger
# London, Jack / The Call of the Wild
# Lovecraft, Howard Phillips / The Shunned House
# ! Problem with lovecraft_the_shunned_house_pg31469: [Errno 2] No such file or directory: './data/lovecraft_the_shunned_house_pg31469'
# Lovecraft, Howard Phillips / The Dunwich Horror
# Lovecraft, Howard Phillips / The Shunned House
# Machen, Arthur / The House of Souls
# Machen, Arthur / The Great God Pan
# Machen, Arthur / The Great God Pan
# Middleton, Richard / The Ghost Ship
# ! Problem with nye-comic-history-of-english-pg11138.txt: [Errno 2] No such file or directory: './data/nye-comic-history-of-english-pg11138.txt'
# O'Donnell, Elliott / The Sorcery Club
# O'Donnell, Elliott / Scottish Ghost Stories
# Onions, Oliver / Widdershins
# ! Problem with perrin_star_of_india_pg42.txt: [Errno 2] No such file or directory: './data/perrin_star_of_india_pg42.txt'
# Piper, Beam / Murder in the Gunroom
# Piper, H. Beam / Murder in the Gunroom
# Piper, H. Beam / The Cosmic Computer
# Piper, H. Beam  / Omnilingual
# ! Problem with piper_omnilingual_pg19445.txt: 'utf-8' codec can't decode byte 0xf2 in position 6412: invalid continuation byte
# Poe, Edgar Allan / The Masque of Red Death
# Poe, Edgar Allan / The Works of Edgar Allan Poe: Volume 1
# Poe, Edgar Allan / The Cask of Amontillado
# Poe, Edgar Allan / The Pit and the Pendulum
# Poe, Edgar Allan / The Fall of the House of Usher
# Poe, Edgar Allan / The Tell-Tale Heart
# Poe, Edgar Allan / The Works of Edgar Allan Poe — Volume 2
# Poe, Edgar Allan / The Works of Edgar Allan Poe — Volume 3
# Polidori, John William / The Vampyre
# ! Problem with prest_varney_the_vampire_pg14833.txt: [Errno 2] No such file or directory: './data/prest_varney_the_vampire_pg14833.txt'
# Rand, Ayn / Anthem
# Rex, Beach / The Barrier
# Rohmer, Sax / The Insidious Dr. Fu Manchu
# Rohmer, Sax / The Golden Scorpion
# Shelley, Mary / Frankenstein
# ! Problem with sinclair_the_jungle_pg140.txt: [Errno 2] No such file or directory: './data/sinclair_the_jungle_pg140.txt'
# Sinclair, Upton / Samuel the Seeker
# Stevenson, Robert Louis / The Waif Woman
# ! Problem with sevenson_kidnapped_pg421.txt: [Errno 2] No such file or directory: './data/sevenson_kidnapped_pg421.txt'
# ! Problem with stevenson_the_strange_case_of_dr_jekyll_and_mr_hyde_pg42.txt: [Errno 2] No such file or directory: './data/stevenson_the_strange_case_of_dr_jekyll_and_mr_hyde_pg42.txt'
# Stevenson, Robert Louis  / The Strange Case Of Dr. Jekyll And Mr. Hyde
# Stevenson, Roberts / Treasure Island
# Stoker, Bram / The Lady of the Shroud
# Stoker, Bram / The Jewel of Seven Stars
# ! Problem with stoker_dracula_pg160815: [Errno 2] No such file or directory: './data/stoker_dracula_pg160815'
# Stoker, Bram / Dracula's Guest
# Stoker, Bram / The Man
# Stoker, Bram / The Mystery of the Sea
# Stowe, Harriet Beecher / Uncle Tom's Cabin
# Swift, Jonathan / Gulliver's Travels Into Several Remote Nations of the World
# Twain, Mark / Adventures of Huckleberry Finn
# Twain, Mark / Adventures of Tom Sawyer
# Verne, Jules / Around the World in Eighty Days
# Viereck, George Sylvester / The House of the Vampire
# Walpole, Horace / The Castle of Otranto
# Wells, Herbert George / The Invisible Man
# Wells, Herbert George / The Lair of the White Worm
# Wells, Herbert Goerge / The War of the Worlds
# Wharton, Edith / Ethan Frome
# Wilde, Oscar / Intentions
# ! Problem with wilde_intentions_pg887.txt: 'utf-8' codec can't decode byte 0xd5 in position 241: invalid continuation byte
# ! Problem with wilde_the_picture_of_dorian_gray_pg174: [Errno 2] No such file or directory: './data/wilde_the_picture_of_dorian_gray_pg174'
# Wilde, Oscar / The Importance of Being Earnest
# Wilde, Oscar / An Ideal Husband
# Wodehouse, P.G. / A Damsel in distress
# ! Problem with wodehouse_a_damsel_in_distress_pg2233.txt: 'utf-8' codec can't decode byte 0x99 in position 1592: invalid start byte

# %%
all_counts = Counter()

for document in documents:
    doc_counter = Counter(document["Tokens"])
    all_counts += doc_counter   
    document["TokenCounts"] = doc_counter
# Out:
# Counter({'VOLUME': 3,
#          'I': 3073,
#          'CHAPTER': 55,
#          'Emma': 776,
#          'Woodhouse': 271,
#          'handsome': 33,
#          'clever': 26,
#          'and': 4408,
#          'rich': 14,
#          'with': 1183,
#          'a': 2960,
#          'comfortable': 34,
#          'home': 125,
#          'happy': 119,
#          'disposition': 24,
#          'seemed': 141,
#          'to': 5099,
#          'unite': 3,
#          'some': 245,
#          'of': 4264,
#          'the': 4819,
#          'best': 82,
#          'blessings': 6,
#          'existence': 6,
#          'had': 1600,
#          'lived': 25,
#          'nearly': 13,
#          'twenty-one': 1,
#          'years': 55,
#          'in': 2088,
#          'world': 78,
#          'very': 1139,
#          'little': 354,
#          'distress': 19,
#          'or': 469,
#          'vex': 1,
#          'her': 2328,
#          'She': 562,
#          'was': 2373,
#          'youngest': 4,
#          'two': 164,
#          'daughters': 6,
#          'most': 241,
#          'affectionate': 9,
#          'indulgent': 1,
#          'father': 158,
#          'consequence': 25,
#          "sister's": 6,
#          'marriage': 33,
#          'been': 757,
#          'mistress': 10,
#          'his': 1083,
#          'house': 88,
#          'from': 532,
#          'early': 40,
#          'period': 18,
#          'Her': 88,
#          'mother': 51,
#          'died': 4,
#          'too': 246,
#          'long': 141,
#          'ago': 29,
#          'for': 1288,
#          'have': 1300,
#          'more': 459,
#          'than': 416,
#          'an': 450,
#          'indistinct': 1,
#          'remembrance': 8,
#          'caresses': 1,
#          'place': 89,
#          'supplied': 5,
#          'by': 554,
#          'excellent': 33,
#          'woman': 115,
#          'as': 1383,
#          'governess': 8,
#          'who': 278,
#          'fallen': 7,
#          'short': 64,
#          'affection': 49,
#          'Sixteen': 2,
#          'Miss': 587,
#          'Taylor': 37,
#          'Mr': 1141,
#          "Woodhouse's": 37,
#          'family': 75,
#          'less': 66,
#          'friend': 159,
#          'fond': 39,
#          'both': 80,
#          'but': 1009,
#          'particularly': 46,
#          'Between': 2,
#          '_them_': 4,
#          'it': 2070,
#          'intimacy': 20,
#          'sisters': 12,
#          'Even': 10,
#          'before': 237,
#          'ceased': 6,
#          'hold': 13,
#          'nominal': 1,
#          'office': 7,
#          'mildness': 1,
#          'temper': 34,
#          'hardly': 70,
#          'allowed': 40,
#          'impose': 1,
#          'any': 649,
#          'restraint': 3,
#          'shadow': 1,
#          'authority': 6,
#          'being': 356,
#          'now': 271,
#          'passed': 54,
#          'away': 134,
#          'they': 387,
#          'living': 17,
#          'together': 77,
#          'mutually': 3,
#          'attached': 24,
#          'doing': 43,
#          'just': 152,
#          'what': 418,
#          'she': 1752,
#          'liked': 15,
#          'highly': 24,
#          'esteeming': 1,
#          "Taylor's": 8,
#          'judgment': 28,
#          'directed': 6,
#          'chiefly': 7,
#          'own': 299,
#          'The': 356,
#          'real': 41,
#          'evils': 10,
#          'indeed': 171,
#          "Emma's": 79,
#          'situation': 62,
#          'were': 588,
#          'power': 41,
#          'having': 145,
#          'rather': 141,
#          'much': 470,
#          'way': 149,
#          'think': 379,
#          'well': 286,
#          'herself': 272,
#          'these': 48,
#          'disadvantages': 1,
#          'which': 535,
#          'threatened': 4,
#          'alloy': 3,
#          'many': 131,
#          'enjoyments': 3,
#          'danger': 31,
#          'however': 113,
#          'at': 989,
#          'present': 85,
#          'so': 899,
#          'unperceived': 2,
#          'that': 1689,
#          'did': 326,
#          'not': 2081,
#          'means': 47,
#          'rank': 9,
#          'misfortunes': 1,
#          'Sorrow': 1,
#          'came--a': 1,
#          'gentle': 16,
#          'sorrow--but': 1,
#          'all': 821,
#          'shape': 5,
#          'disagreeable': 19,
#          'consciousness': 21,
#          'married': 43,
#          'It': 396,
#          'loss': 22,
#          'first': 202,
#          'brought': 54,
#          'grief': 5,
#          'on': 674,
#          'wedding-day': 3,
#          'this': 415,
#          'beloved': 8,
#          'sat': 36,
#          'mournful': 1,
#          'thought': 222,
#          'continuance': 2,
#          'wedding': 8,
#          'over': 128,
#          'bride-people': 1,
#          'gone': 77,
#          'left': 67,
#          'dine': 15,
#          'no': 592,
#          'prospect': 13,
#          'third': 3,
#          'cheer': 4,
#          'evening': 93,
#          'composed': 6,
#          'himself': 141,
#          'sleep': 2,
#          'after': 140,
#          'dinner': 41,
#          'usual': 50,
#          'then': 147,
#          'only': 318,
#          'sit': 38,
#          'lost': 21,
#          'event': 23,
#          'every': 393,
#          'promise': 20,
#          'happiness': 75,
#          'Weston': 384,
#          'man': 211,
#          'unexceptionable': 7,
#          'character': 43,
#          'easy': 27,
#          'fortune': 36,
#          'suitable': 4,
#          'age': 20,
#          'pleasant': 38,
#          'manners': 51,
#          'there': 409,
#          'satisfaction': 26,
#          'considering': 17,
#          'self-denying': 1,
#          'generous': 4,
#          'friendship': 25,
#          'always': 233,
#          'wished': 47,
#          'promoted': 4,
#          'match': 25,
#          'black': 5,
#          "morning's": 3,
#          'work': 19,
#          'want': 88,
#          'would': 810,
#          'be': 1964,
#          'felt': 110,
#          'hour': 72,
#          'day': 148,
#          'recalled': 2,
#          'past': 20,
#          'kindness--the': 1,
#          'kindness': 38,
#          'sixteen': 7,
#          'years--how': 1,
#          'taught': 7,
#          'how': 251,
#          'played': 8,
#          'five': 36,
#          'old--how': 1,
#          'devoted': 5,
#          'powers': 14,
#          'attach': 5,
#          'amuse': 8,
#          'health--and': 1,
#          'nursed': 3,
#          'through': 60,
#          'various': 6,
#          'illnesses': 3,
#          'childhood': 1,
#          'A': 125,
#          'large': 34,
#          'debt': 1,
#          'gratitude': 29,
#          'owing': 3,
#          'here': 129,
#          'intercourse': 12,
#          'last': 118,
#          'seven': 5,
#          'equal': 57,
#          'footing': 3,
#          'perfect': 33,
#          'unreserve': 6,
#          'soon': 221,
#          'followed': 29,
#          "Isabella's": 13,
#          'their': 294,
#          'each': 45,
#          'other': 215,
#          'yet': 102,
#          'dearer': 5,
#          'tenderer': 1,
#          'recollection': 8,
#          'companion': 27,
#          'such': 432,
#          'few': 106,
#          'possessed': 3,
#          'intelligent': 4,
#          'well-informed': 3,
#          'useful': 21,
#          'knowing': 25,
#          'ways': 16,
#          'interested': 14,
#          'its': 116,
#          'concerns': 8,
#          'peculiarly': 10,
#          'pleasure': 114,
#          'scheme': 23,
#          'hers--one': 1,
#          'whom': 71,
#          'could': 822,
#          'speak': 99,
#          'arose': 4,
#          'never': 339,
#          'find': 73,
#          'fault': 20,
#          'How': 107,
#          'bear': 50,
#          'change': 61,
#          'true': 59,
#          'going': 117,
#          'half': 97,
#          'mile': 11,
#          'them': 423,
#          'aware': 26,
#          'great': 262,
#          'must': 561,
#          'difference': 29,
#          'between': 71,
#          'Mrs': 690,
#          'advantages': 12,
#          'natural': 51,
#          'domestic': 7,
#          'suffering': 16,
#          'intellectual': 3,
#          'solitude': 3,
#          'dearly': 2,
#          'loved': 25,
#          'he': 1347,
#          'He': 441,
#          'meet': 32,
#          'conversation': 40,
#          'rational': 18,
#          'playful': 2,
#          'evil': 32,
#          'actual': 3,
#          'disparity': 7,
#          'ages': 2,
#          'increased': 12,
#          'constitution': 7,
#          'habits': 12,
#          'valetudinarian': 1,
#          'life': 73,
#          'without': 209,
#          'activity': 4,
#          'mind': 126,
#          'body': 163,
#          'older': 7,
#          'though': 162,
#          'everywhere': 3,
#          'friendliness': 3,
#          'heart': 63,
#          'amiable': 35,
#          'talents': 8,
#          'recommended': 9,
#          'him': 742,
#          'time': 260,
#          'sister': 26,
#          'comparatively': 2,
#          'removed': 10,
#          'matrimony': 7,
#          'settled': 39,
#          'London': 44,
#          'miles': 16,
#          'off': 97,
#          'beyond': 52,
#          'daily': 10,
#          'reach': 7,
#          'October': 3,
#          'November': 5,
#          'struggled': 2,
#          'Hartfield': 151,
#          'Christmas': 10,
#          'next': 63,
#          'visit': 85,
#          'Isabella': 56,
#          'husband': 30,
#          'children': 57,
#          'fill': 2,
#          'give': 154,
#          'society': 48,
#          'again': 211,
#          'Highbury': 123,
#          'populous': 2,
#          'village': 2,
#          'almost': 85,
#          'amounting': 1,
#          'town': 22,
#          'spite': 24,
#          'separate': 12,
#          'lawn': 4,
#          'shrubberies': 2,
#          'name': 53,
#          'really': 151,
#          'belong': 14,
#          'afforded': 8,
#          'equals': 1,
#          'Woodhouses': 3,
#          'All': 10,
#          'looked': 90,
#          'up': 181,
#          'acquaintance': 62,
#          'universally': 4,
#          'civil': 13,
#          'one': 387,
#          'among': 51,
#          'accepted': 10,
#          'lieu': 1,
#          'even': 122,
#          'melancholy': 12,
#          'sigh': 19,
#          'wish': 133,
#          'impossible': 38,
#          'things': 59,
#          'till': 92,
#          'awoke': 1,
#          'made': 197,
#          'necessary': 34,
#          'cheerful': 27,
#          'His': 57,
#          'spirits': 63,
#          'required': 13,
#          'support': 8,
#          'nervous': 11,
#          'easily': 14,
#          'depressed': 6,
#          'used': 49,
#          'hating': 2,
#          'part': 66,
#          'kind': 76,
#          'Matrimony': 1,
#          'origin': 4,
#          'reconciled': 8,
#          "daughter's": 15,
#          'marrying': 25,
#          'nor': 62,
#          'ever': 188,
#          'compassion': 12,
#          'entirely': 37,
#          'when': 307,
#          'obliged': 76,
#          'selfishness': 4,
#          'able': 67,
#          'suppose': 80,
#          'people': 88,
#          'feel': 95,
#          'differently': 11,
#          'disposed': 19,
#          'done': 141,
#          'sad': 24,
#          'thing': 392,
#          'deal': 90,
#          'happier': 10,
#          'if': 362,
#          'spent': 21,
#          'rest': 50,
#          'smiled': 17,
#          'chatted': 1,
#          'cheerfully': 7,
#          'keep': 32,
#          'thoughts': 38,
#          'tea': 21,
#          'came': 115,
#          'say': 304,
#          'exactly': 49,
#          'said': 481,
#          'Poor': 30,
#          'What': 101,
#          'pity': 26,
#          'is': 1213,
#          'cannot': 135,
#          'agree': 15,
#          'you': 1664,
#          'papa': 29,
#          'know': 326,
#          'good-humoured': 6,
#          'thoroughly': 19,
#          'deserves': 6,
#          'good': 294,
#          'wife': 63,
#          'live': 17,
#          'us': 143,
#          'my': 616,
#          'odd': 25,
#          'humours': 2,
#          'might': 322,
#          'But': 289,
#          'where': 70,
#          'advantage': 27,
#          'This': 108,
#          'three': 62,
#          'times': 26,
#          'And': 222,
#          'dear': 213,
#          'often': 89,
#          'we': 256,
#          'shall': 211,
#          'see': 215,
#          'coming': 88,
#          'We': 89,
#          'meeting': 39,
#          '_We_': 2,
#          'begin': 31,
#          'go': 128,
#          'pay': 25,
#          'My': 107,
#          'am': 410,
#          'get': 67,
#          'far': 68,
#          'Randalls': 89,
#          'distance': 24,
#          'walk': 53,
#          'No': 113,
#          'nobody': 52,
#          'your': 331,
#          'walking': 45,
#          'carriage': 66,
#          'sure': 202,
#          'James': 17,
#          'will': 542,
#          'like': 194,
#          'put': 61,
#          'horses': 23,
#          'are': 446,
#          'poor': 106,
#          'while': 110,
#          'paying': 11,
#          'our': 88,
#          'They': 148,
#          'into': 163,
#          "Weston's": 51,
#          'stable': 2,
#          'You': 301,
#          'already': 45,
#          'talked': 66,
#          'night': 38,
#          'may': 211,
#          'because': 52,
#          'housemaid': 1,
#          'doubt': 97,
#          'whether': 59,
#          'take': 114,
#          'anywhere': 15,
#          'else': 77,
#          'That': 68,
#          'got': 36,
#          'Hannah': 2,
#          'Nobody': 19,
#          'mentioned': 26,
#          'her--James': 1,
#          'glad': 49,
#          'lucky': 9,
#          'slighted': 6,
#          'upon': 132,
#          'account': 57,
#          'make': 149,
#          'servant': 6,
#          'pretty-spoken': 1,
#          'girl': 45,
#          'opinion': 71,
#          'Whenever': 6,
#          'curtseys': 1,
#          'asks': 3,
#          'me': 549,
#          'do': 568,
#          'pretty': 63,
#          'manner': 73,
#          'needlework': 1,
#          'observe': 21,
#          'turns': 8,
#          'lock': 1,
#          'door': 41,
#          'right': 91,
#          'bangs': 1,
#          'comfort': 63,
#          'somebody': 10,
#          'about': 245,
#          'goes': 6,
#          'daughter': 45,
#          'hearing': 31,
#          'tell': 72,
#          'spared': 6,
#          'exertions': 6,
#          'maintain': 4,
#          'flow': 6,
#          'ideas': 15,
#          'hoped': 42,
#          'help': 39,
#          'backgammon': 2,
#          'tolerably': 16,
#          'attacked': 2,
#          'regrets': 5,
#          'backgammon-table': 1,
#          'placed': 15,
#          'visitor': 9,
#          'immediately': 69,
#          'afterwards': 38,
#          'walked': 52,
#          'unnecessary': 8,
#          'Knightley': 353,
#          'sensible': 24,
#          'eight-and-thirty': 1,
#          'old': 82,
#          'intimate': 9,
#          'connected': 11,
#          'elder': 4,
#          'brother': 46,
#          'frequent': 8,
#          'welcome': 16,
#          'directly': 49,
#          'mutual': 5,
#          'connexions': 10,
#          'returned': 39,
#          'late': 26,
#          'days': 50,
#          'absence': 14,
#          'Brunswick': 11,
#          'Square': 11,
#          'circumstance': 33,
#          'animated': 4,
#          'inquiries': 9,
#          'answered': 21,
#          'satisfactorily': 2,
#          'When': 51,
#          'gratefully': 5,
#          'observed': 22,
#          'come': 154,
#          'out': 204,
#          'call': 41,
#          'afraid': 64,
#          'shocking': 5,
#          'Not': 38,
#          'sir': 60,
#          'beautiful': 23,
#          'moonlight': 2,
#          'mild': 4,
#          'draw': 10,
#          'back': 65,
#          'fire': 16,
#          'found': 92,
#          'damp': 6,
#          'dirty': 5,
#          'catch': 14,
#          'cold': 50,
#          'Dirty': 1,
#          'Look': 5,
#          'shoes': 4,
#          'speck': 1,
#          'Well': 80,
#          'quite': 261,
#          'surprising': 2,
#          'vast': 6,
#          'rain': 21,
#          'rained': 1,
#          'dreadfully': 8,
#          'hard': 11,
#          'breakfast': 12,
#          'wanted': 74,
#          'By': 13,
#          'bye--I': 1,
#          'joy': 17,
#          'Being': 2,
#          'sort': 111,
#          'feeling': 55,
#          'hurry': 23,
#          'congratulations': 7,
#          'hope': 141,
#          'went': 45,
#          'behave': 3,
#          'Who': 12,
#          'cried': 81,
#          'Ah': 46,
#          'Tis': 2,
#          'business': 52,
#          'please': 33,
#          'possibly': 17,
#          'regard': 43,
#          'comes': 24,
#          'question': 39,
#          'dependence': 10,
#          'independence': 11,
#          'At': 34,
#          'rate': 12,
#          'better': 164,
#          'Especially': 1,
#          '_one_': 6,
#          'those': 87,
#          'fanciful': 3,
#          'troublesome': 9,
#          'creature': 37,
#          'playfully': 2,
#          'head': 38,
#          'know--and': 2,
#          'certainly': 85,
#          'believe': 100,
#          'sometimes': 36,
#          'dearest': 19,
#          'mean': 56,
#          '_you_': 15,
#          'horrible': 5,
#          'idea': 98,
#          'Oh': 181,
#          'meant': 42,
#          'myself': 100,
#          'loves': 9,
#          'know--in': 2,
#          'joke--it': 1,
#          'joke': 5,
#          'another': 103,
#          'fact': 23,
#          'faults': 11,
#          'told': 78,
#          'agreeable': 50,
#          'knew': 88,
#          'suspect': 20,
#          'knows': 30,
#          'flatter': 5,
#          'reflection': 18,
#          'has': 243,
#          'persons': 11,
#          'chances': 5,
#          'gainer': 1,
#          'willing': 13,
#          'let': 64,
#          'pass': 30,
#          'hear': 100,
#          'behaved': 9,
#          'charmingly': 4,
#          'Every': 34,
#          'punctual': 1,
#          'looks': 28,
#          'tear': 4,
#          'face': 30,
#          'seen': 73,
#          'apart': 3,
#          'Dear': 23,
#          'bears': 2,
#          'sorry': 58,
#          'lose': 19,
#          '_will_': 3,
#          'miss': 7,
#          'thinks': 22,
#          'turned': 29,
#          'divided': 4,
#          'tears': 9,
#          'smiles': 12,
#          'should': 365,
#          'acceptable': 8,
#          'important': 18,
#          'secure': 9,
#          'provision': 3,
#          'therefore': 62,
#          'allow': 47,
#          'pain': 32,
#          'happily': 15,
#          'forgotten': 19,
#          'matter': 30,
#          'considerable': 17,
#          'one--that': 1,
#          'four': 22,
#          'proved': 16,
#          'marry': 62,
#          'shook': 8,
#          'fondly': 4,
#          'replied': 79,
#          'matches': 6,
#          'foretell': 2,
#          'whatever': 15,
#          'Pray': 14,
#          'none': 26,
#          'greatest': 29,
#          'amusement': 16,
#          'success': 10,
#          'widower': 1,
#          'perfectly': 64,
#          'constantly': 8,
#          'occupied': 16,
#          'either': 59,
#          'friends': 80,
#          'wherever': 7,
#          'cheerful--Mr': 1,
#          'need': 42,
#          'spend': 18,
#          'single': 18,
#          'year': 27,
#          'alone': 27,
#          'Some': 14,
#          'deathbed': 1,
#          'others': 59,
#          'son': 37,
#          'uncle': 17,
#          'letting': 3,
#          'solemn': 5,
#          'nonsense': 15,
#          'subject': 97,
#          'believed': 45,
#          'Ever': 4,
#          'since': 62,
#          'day--about': 1,
#          'ago--that': 1,
#          'met': 38,
#          'Broadway': 1,
#          'Lane': 5,
#          'began': 63,
#          'drizzle': 1,
#          'darted': 3,
#          'gallantry': 12,
#          'borrowed': 2,
#          'umbrellas': 2,
#          'Farmer': 1,
#          "Mitchell's": 1,
#          'planned': 2,
#          'blessed': 6,
#          'instance': 9,
#          'leave': 51,
#          'match-making': 6,
#          'understand': 66,
#          'Success': 1,
#          'supposes': 1,
#          'endeavour': 14,
#          'Your': 27,
#          'properly': 9,
#          'delicately': 1,
#          'endeavouring': 3,
#          'bring': 38,
#          'worthy': 17,
#          'employment': 10,
#          'young': 188,
#          "lady's": 7,
#          'imagine': 53,
#          'making': 50,
#          'planning': 3,
#          'saying': 50,
#          'yourself': 54,
#          'idle': 4,
#          'why': 33,
#          'talk': 58,
#          'Where': 14,
#          'merit': 14,
#          'proud': 8,
#          'guess': 24,
#          '_that_': 12,
#          'can': 268,
#          'known': 58,
#          'triumph': 5,
#          'cleverer--for': 1,
#          'depend': 16,
#          'merely': 27,
#          'luck': 9,
#          'There': 129,
#          'talent': 9,
#          'word': 90,
#          'quarrel': 11,
#          'claim': 12,
#          'drawn': 15,
#          'pictures': 2,
#          'third--a': 1,
#          'something': 101,
#          'do-nothing': 1,
#          'do-all': 1,
#          'If': 110,
#          'visits': 14,
#          'given': 76,
#          'encouragements': 1,
#          'smoothed': 2,
#          'matters': 10,
#          'enough': 126,
#          'comprehend': 15,
#          'straightforward': 3,
#          'open-hearted': 2,
#          'unaffected': 4,
#          'safely': 19,
#          'manage': 5,
#          'likely': 46,
#          'harm': 13,
#          'interference': 7,
#          'rejoined': 2,
#          'understanding': 25,
#          'pray': 10,
#          'silly': 11,
#          'break': 12,
#          "one's": 10,
#          'circle': 15,
#          'grievously': 1,
#          'Only': 14,
#          'Elton': 319,
#          'look': 111,
#          'him--and': 4,
#          'whole': 73,
#          'fitted': 1,
#          'comfortably': 11,
#          'shame': 8,
#          'longer--and': 1,
#          'joining': 2,
#          'hands': 22,
#          'to-day': 23,
#          'same': 100,
#          'service': 21,
#          'shew': 28,
#          'attention': 58,
#          'ask': 43,
#          'dare': 59,
#          'With': 30,
#          'laughing': 17,
#          'Invite': 2,
#          'fish': 1,
#          'chicken': 2,
#          'chuse': 22,
#          'Depend': 10,
#          'six': 9,
#          'seven-and-twenty': 1,
#          'care': 51,
#          'II': 4,
#          'native': 5,
#          'born': 6,
#          'respectable': 20,
#          'generations': 2,
#          'rising': 6,
#          'gentility': 6,
#          'property': 6,
#          'received': 36,
#          'education': 15,
#          'succeeding': 5,
#          'small': 27,
#          'become': 12,
#          'indisposed': 3,
#          'homely': 1,
#          'pursuits': 2,
#          'brothers': 4,
#          'engaged': 36,
#          'satisfied': 47,
#          'active': 7,
#          'social': 6,
#          'entering': 8,
#          'militia': 2,
#          'county': 2,
#          'embodied': 1,
#          'Captain': 3,
#          'general': 64,
#          'favourite': 22,
#          'military': 1,
#          'introduced': 8,
#          'Churchill': 189,
#          'Yorkshire': 7,
#          'fell': 10,
#          'love': 113,
#          'surprized': 31,
#          'except': 26,
#          'full': 44,
#          'pride': 18,
#          'importance': 11,
#          'connexion': 20,
#          'offend': 3,
#          'command': 15,
#          'fortune--though': 1,
#          'bore': 7,
#          'proportion': 4,
#          'family-estate--was': 1,
#          'dissuaded': 1,
#          'took': 47,
#          'infinite': 3,
#          'mortification': 11,
#          'threw': 2,
#          'due': 22,
#          'decorum': 2,
#          'unsuitable': 3,
#          'produce': 10,
#          'ought': 94,
#          'whose': 39,
#          'warm': 27,
#          'sweet': 19,
#          'return': 56,
#          'goodness': 6,
#          'spirit': 26,
#          'resolution': 31,
#          'pursue': 1,
#          'refrain': 5,
#          'unreasonable': 9,
#          "brother's": 6,
#          'anger': 7,
#          'missing': 3,
#          'luxuries': 1,
#          'former': 13,
#          'income': 10,
#          'still': 107,
#          'nothing': 228,
#          'comparison': 10,
#          'Enscombe': 35,
#          'cease': 7,
#          'once': 81,
#          'considered': 18,
#          'especially': 21,
#          'Churchills': 14,
#          'amazing': 4,
#          'worst': 19,
#          ...})

# %%
Counter([doc["Horror"] for doc in documents])
# Out:
# Counter({False: 66, True: 58})

# %%
def load_word_weights(lexicon_file):

    ## Create a mapping from words to numbers
    ## {word: emotion: 0/1}
    
    # This creates a depth two dictionary where the default value is 0.
    word_weights = defaultdict(defaultdict)
    with open(lexicon_file, 'r') as lexicon_reader:
        for line in lexicon_reader:
            word, emotion, weight = [e.strip() for e in line.split("\t")] ## split on comma
            word_weights[word][emotion] = int(weight)
    
    return word_weights

load_word_weights("lexicon.txt")
# Out:
# defaultdict(collections.defaultdict,
#             {'aback': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abacus': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 1}),
#              'abandon': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 1,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 1,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abandoned': defaultdict(None,
#                          {'anger': 1,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 1,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 1,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abandonment': defaultdict(None,
#                          {'anger': 1,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 1,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 1,
#                           'surprise': 1,
#                           'trust': 0}),
#              'abate': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abatement': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abba': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abbot': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 1}),
#              'abbreviate': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abbreviation': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abdomen': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abdominal': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abduction': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 1,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 1,
#                           'surprise': 1,
#                           'trust': 0}),
#              'aberrant': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'aberration': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 1,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abeyance': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abhor': defaultdict(None,
#                          {'anger': 1,
#                           'anticipation': 0,
#                           'disgust': 1,
#                           'fear': 1,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abhorrent': defaultdict(None,
#                          {'anger': 1,
#                           'anticipation': 0,
#                           'disgust': 1,
#                           'fear': 1,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abide': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'ability': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abject': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 1,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'ablation': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'ablaze': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abnormal': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 1,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'aboard': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abode': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abolish': defaultdict(None,
#                          {'anger': 1,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abolition': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abominable': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 1,
#                           'fear': 1,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abomination': defaultdict(None,
#                          {'anger': 1,
#                           'anticipation': 0,
#                           'disgust': 1,
#                           'fear': 1,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'aboriginal': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abort': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abortion': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 1,
#                           'fear': 1,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 1,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abortive': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 1,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abound': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abovementioned': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abrasion': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abroad': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abrogate': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abrupt': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 1,
#                           'trust': 0}),
#              'abruptly': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abscess': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 1,
#                           'surprise': 0,
#                           'trust': 0}),
#              'absence': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 1,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 1,
#                           'surprise': 0,
#                           'trust': 0}),
#              'absent': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 1,
#                           'surprise': 0,
#                           'trust': 0}),
#              'absentee': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 1,
#                           'surprise': 0,
#                           'trust': 0}),
#              'absenteeism': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'absinthe': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'absolute': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'absolution': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 1,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 1}),
#              'absorbed': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'absorbent': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'absorbing': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'absorption': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abstain': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abstention': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abstinence': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abstract': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abstraction': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'absurd': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'absurdity': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abundance': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 1,
#                           'disgust': 1,
#                           'fear': 0,
#                           'joy': 1,
#                           'negative': 1,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 1}),
#              'abundant': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 1,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abuse': defaultdict(None,
#                          {'anger': 1,
#                           'anticipation': 0,
#                           'disgust': 1,
#                           'fear': 1,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 1,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abutment': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'aby': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abysmal': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 1,
#                           'surprise': 0,
#                           'trust': 0}),
#              'abyss': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 1,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 1,
#                           'surprise': 0,
#                           'trust': 0}),
#              'academic': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 1}),
#              'academy': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accede': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accelerate': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 1,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'acceleration': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accent': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accentuate': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accept': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'acceptable': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'acceptance': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'access': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accessible': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accession': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accessory': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accident': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 1,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 1,
#                           'surprise': 1,
#                           'trust': 0}),
#              'accidental': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 1,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 1,
#                           'trust': 0}),
#              'accidentally': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 1,
#                           'trust': 0}),
#              'accolade': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 1,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 1,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 1,
#                           'trust': 1}),
#              'accommodate': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accommodation': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accompaniment': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 1,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 1,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 1}),
#              'accompany': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accompanying': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accomplice': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accomplish': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 1,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accomplished': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 1,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accomplishment': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accord': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 1}),
#              'accordance': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accordion': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'account': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 1}),
#              'accountability': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 1}),
#              'accountable': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 1}),
#              'accountant': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 1}),
#              'accounting': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accounts': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 1}),
#              'accredited': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 1}),
#              'accretion': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accrue': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accueil': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'accumulate': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
# ...
#                           'surprise': 0,
#                           'trust': 0}),
#              'azimuth': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'azure': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'babble': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'babbling': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'baboon': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 1,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'baby': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 1,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'babysitter': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 1}),
#              'baccalaureate': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'baccarat': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'bachelor': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'back': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'backbone': defaultdict(None,
#                          {'anger': 1,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 1,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 1}),
#              'backer': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 1}),
#              'backfire': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'backgammon': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'background': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'backhoe': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'backpacker': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'backtrack': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'backward': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'backwards': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 1,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'backwater': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 1,
#                           'surprise': 0,
#                           'trust': 0}),
#              'bacteria': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 1,
#                           'fear': 1,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 1,
#                           'surprise': 0,
#                           'trust': 0}),
#              'bacterium': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 1,
#                           'fear': 1,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'bad': defaultdict(None,
#                          {'anger': 1,
#                           'anticipation': 0,
#                           'disgust': 1,
#                           'fear': 1,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 1,
#                           'surprise': 0,
#                           'trust': 0}),
#              'badge': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 1}),
#              'badger': defaultdict(None,
#                          {'anger': 1,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'badly': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 1,
#                           'surprise': 0,
#                           'trust': 0}),
#              'badness': defaultdict(None,
#                          {'anger': 1,
#                           'anticipation': 0,
#                           'disgust': 1,
#                           'fear': 1,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'baffle': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'bag': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'baggage': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'baggy': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'bagpipes': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'bail': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 0,
#                           'joy': 0,
#                           'negative': 0,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 0}),
#              'bailiff': defaultdict(None,
#                          {'anger': 0,
#                           'anticipation': 0,
#                           'disgust': 0,
#                           'fear': 1,
#                           'joy': 0,
#                           'negative': 1,
#                           'positive': 0,
#                           'sadness': 0,
#                           'surprise': 0,
#                           'trust': 1}),
#              ...})

# %%
emotions = ['anger',
'anticipation,
'disgust',
'fear',
'joy',
'negative',
'positive',
'sadness',
'surprise',
'trust']

def emotion_score(doc):
    token_count = doc["TokenCounts"]
    res = {}
    for 
        for k, v in token_count.items():
        

emotion_score(documents[0])
